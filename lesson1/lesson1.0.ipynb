# %% [markdown]
# # Добро пожаловать на курс ПолуИИ в НГУ!
# ## Занятие 0. Воспоминания о былой математике

# %% [markdown]
# #### Начнем с самой настоящей базы, умножения матриц
# ![image.png](attachment:d5634e1a-31b9-4a3f-9926-8f0f9d2d9105.png)

# %% [markdown]
# ### Добьем не менее классической базы, линейная зависимость
# ![image.png](attachment:c60f54a7-4711-468c-bb6f-e343447b776c.png)

# %% [markdown]
# ### Время искать базис
# ![image.png](attachment:11aa8928-4f42-4fb0-b924-59d9ca168825.png)

# %% [markdown]
# ### Немного плоскостей
# ![image.png](attachment:d5cefd3c-cf42-4f62-9770-79ca803addc2.png)
