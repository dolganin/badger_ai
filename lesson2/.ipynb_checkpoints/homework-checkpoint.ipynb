# %% [markdown]
# # Добро пожаловать на курс И в НГУ!

# %% [markdown]
# ### Занятие 2. Назад в математику, продолжение

# %% [markdown]
# ### 0. Всё еще держим голову в тонусе

# %% [markdown]
# 1. Раскройте $E(x+C), C - const$
# 2. Напишите формулу для $Recall$.
# 3. Представим ситуацию - ваш (будущий) ребенок слышит на улице, что с вероятностью 90% его мама/папа гей. Как вы ему объясните вообще, что такое вероятность и что за такое обычно перо под ребро? *На самом деле, несмотря на формулировку - это хорошее упражнение. Объясняли ли вы случайность без использования всяких отображений и заумно-сложных понятий?*
# 4. Напишите формулу для $Presicion$.
# 5. Напишите формулу для шанса.
# 6. Для чего в сетках нужны функции активации? *Это прям база.*

# %% [markdown]
# ### 1. Вспоминаем еще что-нибудь из тервера

# %% [markdown]
# 1. Назовите главную характеристику случайной величины, и объясните, почему именно она является самой важной в описании какой-либо случайной модели.
# 2. Допустим, у нас есть две случайные величины $\xi$, $\eta$, имеющие следующие распределения.
#    $$\xi = \begin{cases}x=-1, p=0.5 \\ x=1, p=0.5 \end{cases}$$
#    $$\eta =  \begin{cases}x=-100, p=0.5 \\ x=100, p=0.5 \end{cases}$$
#
#    Являются ли они эквивалентными? С помощью какой математической величины можно показать их различия?
# 3. Что такое $Margin$ в машинном обучении?
# 4. Опишите смысл формулы Байеса: для чего нужна, как работает, какие вероятности в ней участвуют.
# 5. Почему плохо описывать предсказания с помощью ступенчатой функции - *то есть, если класс немного выше или ниже прямой, то предсказание кардинально меняется.*
# 6. Опишите стратегию классифицикации $OneVersusOther$.
# 7. Допустим, у нас случается эпидемия сибирской язвы. Она обладает крайне высокой вирулентностью, то есть, заражается почти каждый, кого встречает человек. Вы пишите модель, которая будет определять по контактам  между людьми зараженных. Какую метрику лучше использовать в таком случае?
# 8. Напишите формулу плотности нормального распределения. Напишите для него $E(x), D(x)$

# %% [markdown]
# ### 2. Время сложных вопросов

# %% [markdown]
# 1. Докажите инвариантность $Softmax$ относительно сдвига данных.
# 2. Выведите формулу $Sigmoid$ из формулы шанса честным образом.
# 3. Почему для решенеия очень многих задач используется именно $e^x$?
# 4. (уровень повыше) Честным образом возьмите производную от сигмоиды.
# 5. В урне 2 вида шаров: белые и красные, белых 7 штук, красных 9 штук. Какова вероятность вытащить комбинацию КБК, если шары вытягиваются без возвращения в урну? Объясните свое решение: если использовали умножение, то почему там умножение между вероятностями?
# 6. Допустим, у вас есть $ROC$-кривая, и ваша моделька находится уровнем ниже случайного предиктора. Какой вывод из этого можно сделать?
